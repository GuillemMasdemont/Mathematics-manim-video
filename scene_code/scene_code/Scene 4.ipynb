# %%
from manim import *
# Out:
# Manim Community v0.18.0

# %%
torneig = Table(
            [["-", "7-5", "11-8","10-2", "12-8", "8-4"],
            ["5-7", "-", "2-6","8-3", "9-5", "6-5"],
            ["8-11", "6-2", "-","6-7", "6-2", "9-6"],
            ["2-10", "3-8", "7-6","-", "4-7", "8-6"],
            ["8-12", "5-9", "2-6","7-4", "-", "7-6"],
            ["4-8", "5-6", "6-9","6-8", "6-7", "-"]],    
            row_labels=[Text("Itàlia"), Text("G.B"),Text("Noruega"),Text("R. Txeca"), Text("Suècia"),Text("Xina")],
            col_labels=[Text("Itàlia"), Text("G.B"),Text("Noruega"),Text("R. Txeca"), Text("Suècia"),Text("Xina")],
            include_outer_lines=True).scale(0.3).to_edge(DOWN, buff = 1.73)
        
torneig_taula = [[0, 7-5, 11-8,10-2, 12-8, 8-4],
            [5-7, 0, 2-6,8-3, 9-5, 6-5],
            [8-11, 6-2, 0,6-7, 6-2, 9-6],
            [2-10, 3-8, 7-6,0, 4-7, 8-6],
            [8-12, 5-9,2-6,7-4, 0, 7-6],
            [4-8, 5-6, 6-9,6-8, 6-7, 0]]

# %% [markdown]
# ## Hexagon definition:

# %%
coordenades = {}
r = 3
for i in range(0,6):
    coordenades['p'+str(i+1)] = [3+r*np.cos(2*i*np.pi/6),r*np.sin(2*i*np.pi/6),0]


p1 = 0.5
cercle1 = Circle(color=WHITE, radius = p1)
Italia = Text("Itàlia", font_size=40*p1).move_to(coordenades['p1'])
#Italia_imatge = ImageMobject("Italia2.png").scale(0.2*p1).move_to(coordenades['p1'])
#Italia_imatge.move_to(Italia)
cercle1.move_to(Italia)
#cercle1.surround(Italia)


p2 = 0.5
cercle2 = Circle(color=WHITE, radius = p2)
GB = Text("GB", font_size=40*p2).move_to(coordenades['p2'])
#GB_imatge = ImageMobject("Italia2.png").scale(0.2*p2).move_to(coordenades['p2'])
#Italia_imatge.move_to(Italia)
cercle2.move_to(GB)
#cercle2.surround(GB)



p3 = 0.5
cercle3 = Circle(color=WHITE, radius = p3)
Noruega = Text("Noruega", font_size=30*p3).move_to(coordenades['p3'])
#Italia_imatge = ImageMobject("Italia2.png").scale(0.2*p3).move_to(coordenades['p3'])
#Italia_imatge.move_to(Italia)
cercle3.move_to(Noruega)
#cercle3.surround(Noruega)


p4 = 0.5
cercle4 = Circle(color=WHITE, radius = p4)
RepTxeca = Text("R. Txeca", font_size=30*p4).move_to(coordenades['p4'])
#Italia_imatge = ImageMobject("Italia2.png").scale(0.2*p4).move_to(coordenades['p3'])
#Italia_imatge.move_to(Italia)
cercle4.move_to(RepTxeca)
#cercle4.surround(RepTxeca)



p5 = 0.5
cercle5 = Circle(color=WHITE, radius = p5)
Suecia = Text("Suècia", font_size=40*p5).move_to(coordenades['p5'])
#Italia_imatge = ImageMobject("Italia2.png").scale(0.2*p3).move_to(coordenades['p5'])
#Italia_imatge.move_to(Italia)
cercle5.move_to(Suecia)
#cercle5.surround(Suecia)

p6 = 0.5
cercle6 = Circle(color=WHITE, radius = p6)
Xina = Text("Xina", font_size=40*p6).move_to(coordenades['p6'])
#Italia_imatge = ImageMobject("Italia2.png").scale(0.2*p6).move_to(coordenades['p6'])
#Italia_imatge.move_to(Italia)
cercle6.move_to(Xina)
#cercle6.surround(Xina)


Hexagon=VGroup(cercle1, cercle2, cercle3, cercle4, cercle5, cercle6,  Italia, GB, Noruega, RepTxeca, Suecia, Xina)

# %%
class Escen4(Scene): 
    def construct(self): 
        table = Table(
            [["-", "7-5", "11-8","10-2", "12-8", "8-4","7-3", "8-7", "8-7","8-4"],
            ["5-7", "-", "2-6","8-3", "9-5", "6-5","9-8", "7-8", "6-4","8-4"],
            ["8-11", "6-2", "-","6-7", "6-2", "9-6","10-4", "6-5", "6-7","11-6"],
            ["2-10", "3-8", "7-6","-", "4-7", "8-6","8-2", "3-11", "5-6","10-8"],
            ["8-12", "5-9", "2-6","7-4", "-", "7-6","7-6", "6-1", "6-2","7-8"],
            ["4-8", "5-6", "6-9","6-8", "6-7", "-","6-5", "7-6", "6-8","5-7"],
            ["3-7", "8-9", "4-10","2-8", "6-7", "5-6","-", "9-6", "10-8","5-6"],
            ["7-8", "8-7", "5-6","11-3", "1-6", "6-7","6-9", "-", "5-7","6-5"],
            ["7-8", "4-6", "6-7","6-5", "2-6", "8-6","8-10", "7-5", "-","7-2"],
            ["4-8", "4-8", "6-11","8-10", "8-7", "7-5","6-5", "5-6", "2-7","-"]],    
            row_labels=[Text("Itàlia"), Text("G.B"),Text("Noruega"),Text("R. Txeca"), Text("Suècia"),Text("Xina"),Text("AU"), Text("Suïssa"),Text("Canada"),Text("EE.UU")],
            col_labels=[Text("Itàlia"), Text("G.B"),Text("Noruega"),Text("R. Txeca"), Text("Suècia"),Text("Xina"),Text("AU"), Text("Suïssa"),Text("Canada"),Text("EE.UU")],
            include_outer_lines=True).scale(0.3)
        
        taula = [[0, 7-5, 11-8,10-2, 12-8, 8-4,7-3, 8-7, 8-7,8-4],
            [5-7, 0, 2-6,8-3, 9-5, 6-5,9-8, 7-8, 6-4,8-4],
            [8-11, 6-2, 0,6-7, 6-2, 9-6,10-4, 6-5, 6-7,11-6],
            [2-10, 3-8, 7-6,0, 4-7, 8-6,8-2, 3-11, 5-6,10-8],
            [8-12, 5-9,2-6,7-4, 0, 7-6,7-6, 6-1, 6-2,7-8],
            [4-8, 5-6, 6-9,6-8, 6-7, 0,6-5, 7-6, 6-8,5-7],
            [3-7, 8-9, 4-10,2-8, 6-7, 5-6,0, 9-6, 10-8,5-6],
            [7-8, 8-7,5-6,11-3, 1-6, 6-7,6-9, 0, 5-7,6-5],
            [7-8, 4-6, 6-7,6-5, 2-6, 8-6,8-10, 7-5, 0,7-2],
            [4-8, 4-8, 6-11,8-10, 8-7, 7-5,6-5, 5-6, 2-7,0]]

        for i in range(len(taula)): 
            for j in range(len(taula)): 
                if taula[i][j] > 0:
                    table.add_highlighted_cell((i+2,j+2), color=GREEN)
                    
                if taula[i][j] == 0:
                    pass 
                
                else: 
                    table.add_highlighted_cell((i+2,j+2), color=RED_B) 
                    
          
        nom = always_redraw( 
            lambda: Tex("Dobles Mixtes, Curling, Beijing 2022", font_size=20).next_to(table, UP, buff = 0.25))

        torneig = Table(
            [["-", "7-5", "11-8","10-2", "12-8", "8-4"],
            ["5-7", "-", "2-6","8-3", "9-5", "6-5"],
            ["8-11", "6-2", "-","6-7", "6-2", "9-6"],
            ["2-10", "3-8", "7-6","-", "4-7", "8-6"],
            ["8-12", "5-9", "2-6","7-4", "-", "7-6"],
            ["4-8", "5-6", "6-9","6-8", "6-7", "-"]],    
            row_labels=[Text("Itàlia"), Text("G.B"),Text("Noruega"),Text("R. Txeca"), Text("Suècia"),Text("Xina")],
            col_labels=[Text("Itàlia"), Text("G.B"),Text("Noruega"),Text("R. Txeca"), Text("Suècia"),Text("Xina")],
            include_outer_lines=True).scale(0.3)
        
        torneig_taula = [[0, 7-5, 11-8,10-2, 12-8, 8-4],
            [5-7, 0, 2-6,8-3, 9-5, 6-5],
            [8-11, 6-2, 0,6-7, 6-2, 9-6],
            [2-10, 3-8, 7-6,0, 4-7, 8-6],
            [8-12, 5-9,2-6,7-4, 0, 7-6],
            [4-8, 5-6, 6-9,6-8, 6-7, 0]]

        for i in range(len(torneig_taula)): 
            for j in range(len(torneig_taula)): 
                if torneig_taula[i][j] > 0:
                    torneig.add_highlighted_cell((i+2,j+2), color=GREEN)
                    
                if torneig_taula[i][j] == 0:
                    pass 
                
                else: 
                    torneig.add_highlighted_cell((i+2,j+2), color=RED_B)
        
        self.add(VGroup(table, nom))
        self.wait(1)
        self.play(Transform(table, torneig))
        self.wait(1)
        
        
        
        self.play(table.animate.scale(0.7), run_time = 1)
        #self.play(nom.animate.scale(0.5), run_time = 0.5)
        self.play(table.animate.move_to([-4,2,0]), run_time = 1)
        

          
        p1 = 0.5
        cercle1 = Circle(color=WHITE, radius = p1)
        Italia = Text("Itàlia", font_size=40*p1).move_to(coordenades['p1'])
        #Italia_imatge = ImageMobject("Italia2.png").scale(0.2*p1).move_to(coordenades['p1'])
        #Italia_imatge.move_to(Italia)
        cercle1.move_to(Italia)
        #cercle1.surround(Italia)
        
        
        p2 = 0.5
        cercle2 = Circle(color=WHITE, radius = p2)
        GB = Text("GB", font_size=40*p2).move_to(coordenades['p2'])
        #GB_imatge = ImageMobject("Italia2.png").scale(0.2*p2).move_to(coordenades['p2'])
        #Italia_imatge.move_to(Italia)
        cercle2.move_to(GB)
        #cercle2.surround(GB)
        
        
        
        p3 = 0.5
        cercle3 = Circle(color=WHITE, radius = p3)
        Noruega = Text("Noruega", font_size=30*p3).move_to(coordenades['p3'])
        #Italia_imatge = ImageMobject("Italia2.png").scale(0.2*p3).move_to(coordenades['p3'])
        #Italia_imatge.move_to(Italia)
        cercle3.move_to(Noruega)
        #cercle3.surround(Noruega)
        
        
        p4 = 0.5
        cercle4 = Circle(color=WHITE, radius = p4)
        RepTxeca = Text("R. Txeca", font_size=30*p4).move_to(coordenades['p4'])
        #Italia_imatge = ImageMobject("Italia2.png").scale(0.2*p4).move_to(coordenades['p3'])
        #Italia_imatge.move_to(Italia)
        cercle4.move_to(RepTxeca)
        #cercle4.surround(RepTxeca)
        
        
        
        p5 = 0.5
        cercle5 = Circle(color=WHITE, radius = p5)
        Suecia = Text("Suècia", font_size=40*p5).move_to(coordenades['p5'])
        #Italia_imatge = ImageMobject("Italia2.png").scale(0.2*p3).move_to(coordenades['p5'])
        #Italia_imatge.move_to(Italia)
        cercle5.move_to(Suecia)
        #cercle5.surround(Suecia)
        
    
        p6 = 0.5
        cercle6 = Circle(color=WHITE, radius = p6)
        Xina = Text("Xina", font_size=40*p6).move_to(coordenades['p6'])
        #Italia_imatge = ImageMobject("Italia2.png").scale(0.2*p6).move_to(coordenades['p6'])
        #Italia_imatge.move_to(Italia)
        cercle6.move_to(Xina)
        #cercle6.surround(Xina)
        
        
        Hexagon=VGroup(cercle1, cercle2, cercle3, cercle4, cercle5, cercle6,  Italia, GB, Noruega, RepTxeca, Suecia, Xina)
        
        
        self.play(DrawBorderThenFill(Hexagon), run_time = 2)
        self.wait(4)
        
        #A3 = Arrow(start=[-2, 3, 0], end=[2, 3, 0], color=GREEN)
        
        A1 = Line(start = cercle1.get_left(), end = cercle2.get_bottom(), buff = 0.2).add_tip()
        A2 = Line(start = cercle1.get_left(), end = cercle3.get_bottom(), buff = 0.2).add_tip()
        A3 = Line(start = cercle1.get_left(), end = cercle4.get_right(), buff = 0.2).add_tip()
        A4 = Line(start = cercle1.get_left(), end = cercle5.get_top(), buff = 0.2).add_tip()
        A5 = Line(start = cercle1.get_left(), end = cercle6.get_top(), buff = 0.2).add_tip()
        
        #B2 = Line(start = cercle3.get_bottom(), end = cercle2.get_bottom(), buff = 0.2).add_tip()
        B3 = Line(start = cercle2.get_bottom(), end = cercle4.get_right(), buff = 0.2).add_tip()
        B4 = Line(start = cercle2.get_bottom(), end = cercle5.get_top(), buff = 0.2).add_tip()
        B5 = Line(start = cercle2.get_bottom(), end = cercle6.get_top(), buff = 0.2).add_tip()
          
        C1 = Line(start = cercle3.get_bottom(), end = cercle2.get_bottom(), buff = 0.2, color = GREEN).add_tip()
        C2 = Line(start = cercle3.get_bottom(), end = cercle5.get_top(), buff = 0.2, color = GREEN).add_tip()
        C3 = Line(start = cercle3.get_bottom(), end = cercle6.get_top(), buff = 0.2, color = GREEN).add_tip()
        C4 = Line(start = cercle1.get_left(), end = cercle3.get_bottom(), buff = 0.2, color = RED).add_tip()
        C5 = Line(start = cercle4.get_right(), end = cercle3.get_bottom(), buff = 0.2, color = RED).add_tip()
        
        D1 = Line(start = cercle5.get_top(), end = cercle4.get_right(), buff = 0.2).add_tip()
        D2 = Line(start = cercle4.get_right(), end = cercle6.get_top(), buff = 0.2).add_tip()

        E1 = Line(start = cercle5.get_top(), end = cercle6.get_top(), buff = 0.2).add_tip()
        
        
        ArrowsCW = VGroup(C1,C2,C3)
        ArrowsCL = VGroup(C4,C5)
        self.play(DrawBorderThenFill(ArrowsCW))
        self.wait(2)
        self.play(DrawBorderThenFill(ArrowsCL))
        self.wait(3)
        
        
        Arrows = VGroup(A1,A2,A3,A4,A5,B3,B4,B5,D1,D2,E1)
        
        Animations1 = [DrawBorderThenFill(Arrows), C1.animate.set_color(WHITE), C2.animate.set_color(WHITE), C3.animate.set_color(WHITE),
                      C4.animate.set_color(WHITE),C5.animate.set_color(WHITE)]
        
        self.play(*Animations1)
        
        
        self.wait()
        
        
        Resultats = Table(
            [["6"],
            ["3"],["3"],["2"],["2"],["0"]],
            col_labels=[Text("PARTITS GUANYATS")],
            row_labels=[Text("Itàlia"), Text("GB"),Text("Noruega"),Text("Rep Txeca"), Text("Suècia"), Text("Xina")],
            include_outer_lines=True).scale(0.32).move_to([-4,-1.5,0])
        
        self.play(DrawBorderThenFill(Resultats))
        
        
        Animations2 = [Resultats.get_cell((4,2)).animate.set_color(GREEN), Resultats.get_cell((4,1)).animate.set_color(GREEN), cercle3.animate.set_color(GREEN), C1.animate.set_color(GREEN), C2.animate.set_color(GREEN), C3.animate.set_color(GREEN)]
        
    
    
        self.play(*Animations2)
        
        
        self.wait()   
        
        
        self.play(FadeOut(table),FadeOut(nom),FadeOut(Arrows),FadeOut(ArrowsCW),FadeOut(ArrowsCL), FadeOut(Hexagon))

# %%
# %manim -pql Escena4
